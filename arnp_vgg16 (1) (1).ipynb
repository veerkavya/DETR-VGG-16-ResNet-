# %% [markdown]
# [![Open In Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/NouamaneTazi/number-plate-recognition/blob/main/notebooks/DETR_license_plates.ipynb)
# <a href="https://colab.research.google.com/github/NouamaneTazi/number-plate-recognition/blob/main/notebooks/DETR_license_plates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Fine-tuning DETR for license plates detection
#
# In this notebook, we are going to fine-tune [DETR](https://ai.facebook.com/blog/end-to-end-object-detection-with-transformers/) (end-to-end object detection with Transformers) on a [custom moroccan license plates dataset](https://www.kaggle.com/elmehditaf96/moroccan-vehicle-registration-plates). The goal for the model is to recognize license plates in pictures.
#
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2020/05/Screenshot-from-2020-05-27-17-48-38.png)
#
# Also big thanks to Niels Rogge from Huggingface for his [Transformers tutorials](https://github.com/NielsRogge/Transformers-Tutorials), as well as the creators of [this notebook](https://github.com/woctezuma/finetune-detr/blob/master/finetune_detr.ipynb) and [this notebook](https://www.kaggle.com/tanulsingh077/end-to-end-object-detection-with-transformers-detr), which helped me a lot in understanding how to fine-tune DETR on a custom dataset

# %% [markdown]
# ## Set up environment

# %%
# !pip install -q timm pycocotools scipy
# !pip install -qU pytorch-lightning transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 34.0 MB/s eta 0:00:00

# %% [markdown]
# ## Download + preprocess data
#
# Here we download the [license plates dataset](https://www.kaggle.com/elmehditaf96/moroccan-vehicle-registration-plates) hosted on kaggle (in [YOLOv4 format](https://github.com/AlexeyAB/darknet)) and convert it to [COCO Object Detection Format](https://cocodataset.org/#format-data).
#
# We can use [fiftyone's converter tool](https://voxel51.com/docs/fiftyone/recipes/convert_datasets.html) for that.
#
# For the sake of demo on kaggle we're only gonna use 20 images from that dataset.

# %%
# !cd ../input/coco-lp-preview/coco_lp/ && ls
# Out:
# desktop.ini  train  val

# %% [markdown]
# ## Create PyTorch dataset + dataloaders
#
# Here we define a regular PyTorch dataset. Each item of the dataset is an image and corresponding annotations. Torchvision already provides a `CocoDetection` dataset, which we can use. We only add a feature extractor (`DetrFeatureExtractor`) to resize + normalize the images, and to turn the annotations (which are in COCO format) in the format that DETR expects. It will also resize the annotations accordingly.

# %%
!#!/bin/bash
# !kaggle datasets download fyfek1151kavya/coco-format-number-plate-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fyfek1151kavya/coco-format-number-plate-dataset
# License(s): unknown
# Downloading coco-format-number-plate-dataset.zip to /content
#  98% 79.0M/80.7M [00:04<00:00, 24.4MB/s]
# 100% 80.7M/80.7M [00:04<00:00, 18.5MB/s]

# %%
# !unzip /content/coco-format-number-plate-dataset.zip -d /content/coco-format-number-plate-dataset
# Out:
# Archive:  /content/coco-format-number-plate-dataset.zip
#   inflating: /content/coco-format-number-plate-dataset/README.dataset.txt
#   inflating: /content/coco-format-number-plate-dataset/README.roboflow.txt
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate129_jpg.rf.e928edf270fed0fba46d5699d93b9fbd.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate131_jpg.rf.9e3730e2cd692a80f1b07ec97c5cef31.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate180_jpg.rf.f6e8553a572c159b108dd689c9016a86.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate185_jpg.rf.06d0f30fd4a2a242512eae9d25cb9c71.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate231_jpg.rf.0a1a8a8dab824940015f8027c8dd82b9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate255_jpg.rf.7a422e2ea0429700cee4a3ce7fd4f58f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate273_jpg.rf.bb99a62c4d3f296f2397dffbd3318bac.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate282_jpg.rf.74c3af8438484f3c75282242649e998a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate302_jpg.rf.8d5d3af6d610d833b1faaca20f4cf922.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate308_jpg.rf.becc0c1fdfb4cfb665bd448d1ce3b5f7.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate313_jpg.rf.bc0f511fe1e10301c647bc175de1ac9b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate322_jpg.rf.418de9041fe58975e522bfeab05eea10.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate337_jpg.rf.44dd5038367858d5a4715768566a1dc0.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate388_jpg.rf.0cf9ac66decc1d61448bf12e06663604.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate405_jpg.rf.848fe380f259b911e94722890b2a42e1.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate412_jpg.rf.a781449014d2cc7c82334bfb23772996.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate467_jpg.rf.9e40b2c51c5abcf3d7ebf08e252ec810.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate477_jpg.rf.94b6a8674a247f42b81fb83d6314d656.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate532_jpg.rf.2e45848c498c840a6dd683910727a7c3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate548_jpg.rf.f5ab27ed18bc3a9e59234c90432a0d3b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate563_jpg.rf.6dd1729286a4254a713f0b7ab85faaf5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate564_jpg.rf.b7de894516c3fd5902e50fcb2bb4c075.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate581_jpg.rf.e2bfde3ab7d7fac3b031ddbdfaa362fe.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate623_jpg.rf.68aceb8d83d2012519e3c86939ee37c4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate628_jpg.rf.8ca734ddf8ebe105333e2fd28e93cf37.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate635_jpg.rf.4a4ef9308d52e328e67174df996184e9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate64_jpg.rf.c3342760f0345c480c2e52612ea5c7a3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate650_jpg.rf.e635fa865a95b29f4146259f6678f0ea.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate657_jpg.rf.5cf99f2ac7d692aa2553f5cf19125f0f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate67_jpg.rf.3d85897b0cf8050b4e10f1f13b8b97dd.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate701_jpg.rf.e122c9edc37ed7ee906fe62e9a99c126.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate736_jpg.rf.03d06217377e74957d83a85b0b5a944a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate767_jpg.rf.48cd8b9a407e2ad7d4048a86301a7360.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate785_jpg.rf.ea66fefb094b26f600967d7da9b97832.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate787_jpg.rf.5215b8cc120f79ac9bf5218e6b8356b1.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate794_jpg.rf.dce1ff03ab46bf58b3c39fc855bec650.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate800_jpg.rf.24955096388d8b772b4a3b79276d7b1d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate806_jpg.rf.9c3a70907b0e7b9c6ac8bfc38bb48a81.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate811_jpg.rf.f26c1030a89bf345c8a92878b32bd556.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate890_jpg.rf.4e49c8609911278d12e43cd6caa81bce.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate892_jpg.rf.db60c7d498744bb3119dd2f92af86152.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate89_jpg.rf.f2986e0479abfe6c280192ed4b972d34.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate942_jpg.rf.6230be457d8c5e50fba26181c4fbb3c6.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate944_jpg.rf.3297b3591fb0b66b3fc15e26458d1cef.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate953_jpg.rf.76e7b6ef663d7e6133165dc5a1cd8d81.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlate996_jpg.rf.f7aac527faeba5a73c8b18cdab38007d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1047_jpg.rf.7566af54749f899eea168f80836b72a9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen10_jpg.rf.8a5763a8d9be4a221c7df6dd604dbe5c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1127_jpg.rf.439f0efe813d01ad1de929a27527323d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1153_jpg.rf.2b3e7fe5588cc8b9f873b84cd8174c4a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1155_jpg.rf.b26f32598c1675120989dc733cb4e1d1.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen116_jpg.rf.8c4592cfcdade918913b9ddc15c4690b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen120_jpg.rf.e33cc59457ab83896f4b11b9e4029a19.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1226_jpg.rf.b1f7574e141a32f5a9d5687347121cb6.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen123_jpg.rf.c114f7bae74786df3b1533237cda3f11.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1240_jpg.rf.36ecf026ab6f6837167dc747b7e764e5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1259_jpg.rf.eae53e9d18fc65f6ad5695c381a8e563.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1283_jpg.rf.8d4cba76e4f7b1676434e61b10845751.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1338_jpg.rf.272132969ba5c51233ede9f6b6c0fe7e.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen134_jpg.rf.0980b368bae41bd31a6435616d4e32aa.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1372_jpg.rf.32af869b83f7b158b8a5f01b5d66e92e.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen13_jpg.rf.664399f4fa9776a75ffa80ca53a110ba.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1401_jpg.rf.051067a6803414cf0c018beca998c4ab.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen140_jpg.rf.f5d38356e7aca27ccc939198a2a3835e.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen141_jpg.rf.beb1e1317683ed8308f3bb5737c882c6.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen144_jpg.rf.b57fad6aae01a7236c030cea00355302.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1457_jpg.rf.1d3a83f91e977c154681b38dc4744d4b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1471_jpg.rf.bf795fbafa5e8a9706ca8b5bed058bca.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1484_jpg.rf.d2903843a4b14444d38b70e433f0f8fb.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1546_jpg.rf.ec29b4e5a944b32eeb4e1d958bde5536.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1547_jpg.rf.baa9ee75535aa20e9670c1094759a14c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1553_jpg.rf.209c073142976ec26c668e1af12eaea7.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1555_jpg.rf.b2b465c313bb76df65e7255176047633.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1558_jpg.rf.f000f8cae62c7c587e526f781921ad23.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1570_jpg.rf.f44519d32b3836c0096ced1e3c708f3a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1573_jpg.rf.a6227e9ef6511ae8681997cdffc85886.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1584_jpg.rf.c03c5ea559135163860faf6c0349bbe9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1591_jpg.rf.40bd8cb4063f1061f8646db696313434.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1598_jpg.rf.c7f355877a2d8b369168d17958e80108.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1651_jpg.rf.037172e423fb7d1b2cf22cb77a5adff1.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1679_jpg.rf.c44bfd7e4626a20291992e091b27df4c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1686_jpg.rf.0a0994e3adb1b153efc6de09e22c26a7.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1691_jpg.rf.93730f480f6eb9d6b15a6bff5601fadf.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1731_jpg.rf.7d214e56fa5eb8b036aaf6ea5df2721a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1800_jpg.rf.5ad69fbf5a6c91f25f3cb382c7368c30.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1804_jpg.rf.674e375087e20082c9f8c952ead30591.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1815_jpg.rf.8d3d6167eb49067ea920790bc4a9be4c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen182_jpg.rf.bdf6655347ed263ef647b603348a90fb.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1847_jpg.rf.dd06e667264620ba8c5e13bc50625cc0.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1852_jpg.rf.362618e445abee7fd7a92fa7332f73fe.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1864_jpg.rf.91baa02f56e1adaaefb7e52c11c7a71d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1887_jpg.rf.49e6ddc3772f119a5c66b6b820160a05.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1911_jpg.rf.a03d53494720f351e4359e44d02d6354.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1943_jpg.rf.ff48bf73e624029c1fa40530c19bcc49.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1978_jpg.rf.640f5d57f669083e84608d3bdf7f4a8b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen1990_jpg.rf.82aca6d185fb9e55c7b21fe269362ac8.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2005_jpg.rf.4d6768973f889f5eb8eb6954f1bbab87.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2022_jpg.rf.2d3409fdce5317303b99d12eae0193d9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2051_jpg.rf.9740c574997aba4b94107ec53c46c236.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2054_jpg.rf.47a2c865324a58dc4ad1eb6aa22e1b12.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2080_jpg.rf.4015031ccd3adeb78aa7f0545ef51e4e.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2096_jpg.rf.489ebedc268f8b312c43b2a5358ab8e1.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2103_jpg.rf.d752f6c2f07e648a66db3351a494abda.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2132_jpg.rf.d0dc00b779e4df11eec5704a2299f435.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2152_jpg.rf.c9f43b2f7e3765a9c8b1f27141b49010.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2168_jpg.rf.d6f27eba686d33133f0b02e72d5445bf.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2183_jpg.rf.c3124464aa15c3c7f487f71580b11e7f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2208_jpg.rf.fbf4ae839b086997a32dbd891bee0dbf.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2245_jpg.rf.8a657b0fb83a8eca3c6a68d13a3615fa.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2254_jpg.rf.4995808e0337c1af38718d5e555e5341.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2257_jpg.rf.d345ea04904953b99cfad39cbea8a127.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen2292_jpg.rf.2d31520a0161f72c2af8fee15eb1eaa3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen238_jpg.rf.e1dd0282c01e3894c0b1c14e1589c72f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen246_jpg.rf.8eb0a0fc72dd16d59bc8e28283c010d5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen252_jpg.rf.436c0ab6f37c80a36fca4940d90b857d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen266_jpg.rf.16f0f9fefac8d47ba2a833b05117cd69.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen288_jpg.rf.960b468a2e683592475d545a86416d9f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen305_jpg.rf.1c3bc49f40016b40959daa693b2c9eb5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen324_jpg.rf.cf0573b1c9ec9e8be9f630e6f5d71fb4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen333_jpg.rf.6df63b542884f0349304ec89cb4851d4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen334_jpg.rf.ec7a9d276dc25144ee51b19fa67e057c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen337_jpg.rf.d5bfc6671a7b5bc62f787f543f07799a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen348_jpg.rf.c0ce393ee45d840766c16009d0ae6909.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen34_jpg.rf.ce5f4efe77644e53d48d66b2311835fe.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen381_jpg.rf.b5e56fcbe3833937e276a77750f456f9.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen390_jpg.rf.589340a922e372b42a204f6476445431.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen397_jpg.rf.4b87f45495aa519b4ab73443c1362785.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen419_jpg.rf.54582bd58158b8c01813aed2e01e6c24.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen426_jpg.rf.041d47220973b70e92ca06bb4736901c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen45_jpg.rf.3a7caceba32a9af5bab47f061bbd39f8.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen498_jpg.rf.78dd2411068f1c1ce267d0116f9b7da7.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen506_jpg.rf.bedf7af7264a67ecc2c5dd49177dd178.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen50_jpg.rf.d438ffe9a88b3b1ee0f439797a3eb8ed.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen523_jpg.rf.a974100b30c5a82dfa209caa4fa36948.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen582_jpg.rf.b9727cc84cb2939115b858d61988b562.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen603_jpg.rf.5b8d5710847e290e6fb7fac3bc6b12ce.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen607_jpg.rf.71181ac0c4de3f3ba705b14e5ca8728b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen630_jpg.rf.828c0e77530e5b2b38627c6c42582ca0.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen641_jpg.rf.d27212b710a66f0d4c973df47e64a6f3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen658_jpg.rf.789c8cb7d778126d108dba660b0d24a4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen701_jpg.rf.7ef352d9482f175da5bdf59ce9b15155.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen722_jpg.rf.a567de19d4191b6e0bbe9070c8ae52ae.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen762_jpg.rf.15e39258db1d4c3f9a2b759d3e13f6fa.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen803_jpg.rf.6800a84649d6624dc00d672ea7694400.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen824_jpg.rf.18b13c11d37b593f5e15d24fa868bbc8.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen832_jpg.rf.b0acbdfbcb97f797ac2a6659988b9ccf.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen862_jpg.rf.43ad62584ee736c36b7870a731721c15.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen863_jpg.rf.adee7fa379d55a37b966a17623e47d78.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen872_jpg.rf.762fbe7d84b31799a1a52f2674947200.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen877_jpg.rf.fc425518a873a024287d1ddc54bbc69d.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen880_jpg.rf.dce63d08bc8d6ce9a893af02b253815c.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen955_jpg.rf.0f862545cb5c0271f259147e135b98e5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen968_jpg.rf.e337f98b4b26d9f38a3af5786198c57b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen979_jpg.rf.179f3b91a4889fefad8dc589a5aa2b5a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen988_jpg.rf.acff231d720957cfadce0f96ea1ab5e0.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen98_jpg.rf.5033d5849308741f19d3565fa064a09a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/CarLongPlateGen995_jpg.rf.941df3f880322ad9733ec0a9723bfa81.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars119_png.rf.6c3a1a1816e24832f0cd54c049f2a7c5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars11_png.rf.048e68ea33dc2026e94a5702e7d70970.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars12_png.rf.a6cfdb55849053dfeae7fd7365ebee60.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars137_png.rf.24b8ecfd4462e15543589e6bd75a8998.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars164_png.rf.7d2b0759c4b0f8d1c6603de785447a6b.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars174_png.rf.794d2f6353a38571803e0d9cbf389b85.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars218_png.rf.a83372cd7d35ad8069f46e68886b07a2.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars236_png.rf.b26dcd88bce2d14d584b2bd25a742ae5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars244_png.rf.d0efb0cc9eb62cbe74bfb38d3c3e84f8.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars249_png.rf.79dd278fbb96649598fd1dd0fd9bf042.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars305_png.rf.cf8478def437edac857584fb9239c6a0.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars306_png.rf.b424bd1fad2fb8234458654b757929d5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars314_png.rf.217f7438d6387981b742874468f78cf5.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars344_png.rf.371b6b9f48cd6cf491b3172e64faeab7.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars372_png.rf.481c063ce4622f30fc1b6cb387d735b6.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars375_png.rf.d137539e3201914f639baa49168b95e3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars379_png.rf.24e8ec2fd6d57ced699dc418992fb3ee.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars380_png.rf.65393449d71390c5f42002c870ed692f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars381_png.rf.efa9e398fbdc60b8ebed2a61f59ec3ba.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars429_png.rf.18a12196d55bba7899070edb812c4ccc.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars60_png.rf.f581682bf4c527d33cfd3cc7c0b952de.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/Cars87_png.rf.7a348296e97d371d41eddfcfbfd7724a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/_annotations.coco.json
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi106_jpg.rf.1a0ba39879ea2090c7e7b61f3572578a.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi11_jpg.rf.28dcfb3876bb942e96dc7546ab89d2b4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi26_jpg.rf.6396416da4dfd1d8c756c9bf7be8a408.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi64_jpg.rf.32615f6c116e95b64a95456bf54d4e46.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi92_jpg.rf.9515f4b84289921669e2abe830caf074.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/boderquandoi95_jpg.rf.fc114114dd5c07e350cf553b3747e639.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessngoaigiao4_jpg.rf.542ea69d3c21f6c92243628292dcb0d4.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi100_jpg.rf.4e8963edf9486c8fc9e8b68d0f213f76.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi24_jpg.rf.47ebe8e2db09aec31f4e4c3ee9f52573.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi27_jpg.rf.1cb46bf4d65f1f486aed16fe2e819432.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi35_jpg.rf.1b5f93990e274b122c7f6b945c66163f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi37_jpg.rf.b451bd5848f1b8c1de20f06530779a6f.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi56_jpg.rf.87c02c79c9e0ba0de680360384bcbb99.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi70_jpg.rf.fce075c03df35e5d52b9fa9b150e21a3.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi74_jpg.rf.20f8900d911dc7630a9c438f327724da.jpg
#   inflating: /content/coco-format-number-plate-dataset/test/brightnessquandoi89_jpg.rf.4d0f37f4ee17aee98fa7cd5bb51a13e8.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate0_jpg.rf.20d1495f865ab5eaa4bf354901969178.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate100_jpg.rf.2186bfce8e2e39119f4970ce31df8e52.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate101_jpg.rf.72b9c2a487f7da07fe98b8f0c974b9d2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate103_jpg.rf.15a26579c7cbe51cd2cd9df95f0354ac.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate104_jpg.rf.91011b81d3548259d8ac783675e78122.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate105_jpg.rf.712ca79220593712e63eb6a04e0ccb08.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate106_jpg.rf.fadf9e58a8dcd6959e14ad46f197b72e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate107_jpg.rf.2f222305ad8639151b49eaa906717882.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate110_jpg.rf.3d8f8cec83b8703a4fa9bebf7cfbbfa9.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate112_jpg.rf.2794c9e985182cdeae6e198192108b28.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate113_jpg.rf.70e3f6d97acb1b0c29905c14641070aa.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate115_jpg.rf.8e7a44ed40b2537a02bdd94fab4b306b.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate116_jpg.rf.b6fca2932e25a9404d5d74e6986a4f4f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate117_jpg.rf.d09e0d7040f2561abfcde9ff836811fc.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate118_jpg.rf.4ab8bf6ed3d57a3e1628ddf18a30c89b.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate119_jpg.rf.9217fa3b250691d505756bb0361291a8.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate11_jpg.rf.5eb7a6e13463a33d47e34290d7515025.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate120_jpg.rf.f6fe684c238b32c43a3d152adc737d06.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate121_jpg.rf.329da9f6013a1e6a99f471b8e3ed0819.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate122_jpg.rf.d45fa1e9970fc8bd4fe005b5d1bb62aa.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate123_jpg.rf.54e839f058d0df519e22796a9b9c7ada.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate124_jpg.rf.efc2e953fb1123e4746e08479f75bff0.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate125_jpg.rf.2957c45aa3080f9a0d8eb99f97ccdbe6.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate126_jpg.rf.7f0aa6d818a0527b47c6ad71f235556f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate127_jpg.rf.b874097e5ba5ff14043c29f03150ef5e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate128_jpg.rf.b095d223764fc212d6f53fbeb1d32262.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate130_jpg.rf.7bd95d07df6152855fd28ed5c1c1b129.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate133_jpg.rf.0d1b33fe085566624c65b94fa8f8b407.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate134_jpg.rf.6e2c34566aca15e0e014a423ad7c4b4c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate135_jpg.rf.178293055b5699415ef8252d6be79f35.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate137_jpg.rf.fb16aea53dff1c59a06394ed2ced7a81.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate138_jpg.rf.10cf0b79e4b7ae7aa095af1beac7d914.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate139_jpg.rf.02866fe233b9bfda9dd290bf0e23fa30.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate13_jpg.rf.8517495913677b9a6c42a3e5e2536b6b.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate140_jpg.rf.b4e31eaf3a4a57ed153dfa63df34fb94.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate141_jpg.rf.3850e1cbc2d99f5ad3444c244c74d351.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate142_jpg.rf.537eaae3f64e441404f7bb493da5848a.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate143_jpg.rf.2f1f624254d8bf73366f4d260c82caf0.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate144_jpg.rf.0287414dff9569b27675f87240cb988c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate145_jpg.rf.f2bc14ef5bcc88ee81b9530740af2de7.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate146_jpg.rf.4411e3b67ab3f2e57b9595c2b3e42ad6.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate147_jpg.rf.37f69188387854bbfc454e5e663da49b.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate148_jpg.rf.840bee2e3668abf1731eb3a5810ec11f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate149_jpg.rf.f94dd08132696a5c515104eab8dfddbb.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate14_jpg.rf.4ee91374dfc72034fe5e0e8ef61b6139.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate150_jpg.rf.ff2c89c6130ff69889cc68ed934cee39.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate151_jpg.rf.db40e06d3bca0965dfb9fe0ceb760e46.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate152_jpg.rf.9f44591567019d706f53f887372b387a.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate153_jpg.rf.9a7e3b86e0f3669b339d66e33d75ae95.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate154_jpg.rf.931e696b4cbab35f26aff6b5dfba9409.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate155_jpg.rf.510c9a16ed091c39cb7914def6679853.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate156_jpg.rf.57a936778bf1e0dbc01381792d8dcc18.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate157_jpg.rf.175837e28b61a08c6c3158de954bebcf.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate158_jpg.rf.9a3216f1205c1dd1998936496c4ec97e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate159_jpg.rf.08d659e12b22052a8419a151ef7cc02c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate15_jpg.rf.e91704762ddd77b9b130d1f4f8e230ed.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate160_jpg.rf.0cd82a31c1cfbb0b0b3cba8a11936661.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate162_jpg.rf.e8ce14f0b835dadc1e10b61cc136aa80.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate163_jpg.rf.957dde6466da5b557e47320740770a57.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate164_jpg.rf.a94add197e7a4f1d192511ce18476d8f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate165_jpg.rf.68e3b6f72686df806edee2e690761a35.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate166_jpg.rf.824ab665563eea02bf64e0a6d218897d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate168_jpg.rf.2d11f1176ef19e5f6933948f7ac74651.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate169_jpg.rf.08a7e71351862f7f0bbc12c43793e745.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate16_jpg.rf.dd5243e09f1c0c9e7208f2011691e0ca.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate170_jpg.rf.0fa67cd3fcb9b736012edcfbf75345ab.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate171_jpg.rf.66e08ecd971ef786bccce3c3b65124df.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate172_jpg.rf.d9820ac24e78264b71f6d3b216715950.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate173_jpg.rf.c02ee255113e26925dcfdc055c876b13.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate175_jpg.rf.a3079ed9a946db1c2eae36b8ec794ff2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate176_jpg.rf.3fae4b09ca82cd060a13a96a62b470be.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate177_jpg.rf.8728a58488cd90f5269258e26a1602a0.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate178_jpg.rf.b50a42865d04cd6d9f735af65228c3f9.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate179_jpg.rf.d25329ac157147eeac63a29a4e5ffa0d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate17_jpg.rf.2d7f108291d3d95783509a501df0ca13.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate181_jpg.rf.a3e1e1bb6505e3714e6b327210ac2446.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate182_jpg.rf.d1121efa38477c41f16a07b2bbfcd031.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate183_jpg.rf.cc82754e2b26c82b9f92c2d9069ed719.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate184_jpg.rf.17e725b07f73742b910a95bf7b7c9450.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate187_jpg.rf.c939a8527c94108c0cfcdcf510243a65.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate188_jpg.rf.0d425637cec6f8e323838346be1e2172.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate189_jpg.rf.ecd2b7c53097d3b65b09d4bd09bf1d45.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate18_jpg.rf.afd4595d40227ec34b5330f5586834c0.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate190_jpg.rf.27dc9a909b974e0f4f93693057cc0fec.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate192_jpg.rf.cbdc9edc2bdffa8435e836c050a29f59.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate193_jpg.rf.a73dc416a9a510824e3f4315eea127bc.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate195_jpg.rf.f88051387dcdb548cdd0aeecd449b4e2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate196_jpg.rf.c38b4488aa8743cd58bf24af83b458c2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate197_jpg.rf.20f458e299a3fca44d35dcafc089e3e4.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate199_jpg.rf.7860e2260b1f040de945f41957c9c763.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate19_jpg.rf.199ba28b5e786391ebb79c5c12a4d91d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate1_jpg.rf.caafacf0d3978d2171702ddea93071a9.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate201_jpg.rf.b094ef0f6e76fb3f29af6f1235a8b664.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate203_jpg.rf.c036f67aba4e3d6167d161431f2e405b.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate204_jpg.rf.6fb06f7cf18ffba980be163d6b497c92.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate205_jpg.rf.6de93f58fe37dbe481a713b8af84147a.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate206_jpg.rf.b025648f924efb77a71853b9d8feed14.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate207_jpg.rf.819f5c10e57c4f59138920256f884666.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate208_jpg.rf.bb9c35dc9e5f921122283071111d0b38.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate20_jpg.rf.247dce00a92aa6db344b1c3bc92a609e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate210_jpg.rf.d19b3aba58084a11912c5cec9604c440.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate211_jpg.rf.9d375ad6791f97f69700ef4d30c905d6.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate212_jpg.rf.41c1d7578737c64c0aebfd695d998792.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate214_jpg.rf.035e9db2c0cbd2f4d2ca57132222b561.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate215_jpg.rf.06239676fbb66a42964958122e2e8080.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate216_jpg.rf.1b5ccd41f23c11ac598a9469ee32ac3d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate217_jpg.rf.3b03c1236f9d74c2db4c6d1c5bfab061.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate218_jpg.rf.718d96d2f1dcc8cea50f8202a810c909.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate219_jpg.rf.3d405c2da32f499a3332d4673d66aca5.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate21_jpg.rf.de6d852f2f65a6eb579bef497218b5a2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate220_jpg.rf.9babab1309d437ffaa009e4fe184273d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate221_jpg.rf.c40c658c506cd3425b51a6e974d38218.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate222_jpg.rf.8a49b02b565e64b1e2ed867ebd998984.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate223_jpg.rf.96a3491c0ac54e973aea022a5ab80dd9.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate224_jpg.rf.6492708ae7be98ddb17500882fe02cc6.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate225_jpg.rf.27df19ceab55ac05dc4b083a39734975.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate226_jpg.rf.e9a015c9287ad2d8ca176f4e0f53fd35.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate227_jpg.rf.9ccd44ec2c141c1cd5831f370ba952f5.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate228_jpg.rf.98b43479eae3c84bd061f53bb83c62da.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate229_jpg.rf.ec977d55cbc4249917d9f40fd2dda9e7.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate22_jpg.rf.5f7ba99a7a5391d07412c3ce4efec833.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate230_jpg.rf.b79cc0638139e30b2f01089b3852f3f8.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate233_jpg.rf.680435005c9f84a3c29ae939cb26d750.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate234_jpg.rf.f5001150495685bbdf8c688068ccd006.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate236_jpg.rf.98dbbfbd92af6721d5716f529d146eef.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate237_jpg.rf.d4ecb42346e06baf9742f7c45c29a0e5.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate238_jpg.rf.aee561d89cc7843ea386e76fe9be2a27.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate239_jpg.rf.a5020d0dac6335f72109555748988237.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate23_jpg.rf.b3a5f53a77caee9c20228fdac12257d2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate240_jpg.rf.ef9b56258de98ea29f5cbe7cd7e29970.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate241_jpg.rf.0f3faf610c516ac4aa4312b7f5f9fba3.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate242_jpg.rf.9ee96a495be77a67bac84cd67bc00501.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate243_jpg.rf.df3ed091edd28a772d0503d06194371c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate244_jpg.rf.aa28405e6a37167c4d4edeefff18ced7.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate245_jpg.rf.d2f41048a57a800dfbeea4922f1df5fd.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate246_jpg.rf.3361f384a473ae548e7628a195b05049.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate247_jpg.rf.1562f1959e169e941a50cd119821b28f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate248_jpg.rf.5011770d532a93e4080bf32530c171e3.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate249_jpg.rf.12f054804b849f6dd36c500f062495ff.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate24_jpg.rf.74a445ca27c5a28b26bada1b4fbee687.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate250_jpg.rf.83e61a295bbcd15f5ad6da8ef235ea2e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate252_jpg.rf.bf04d21cda64403ee75e063bd54653b2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate256_jpg.rf.65fdfc3eedb13c464d5d58aa71eed582.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate257_jpg.rf.489880f011d47c0360549042ac86c7dd.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate258_jpg.rf.7b0cb1567ecbce1ad03da02e8792c27e.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate260_jpg.rf.058bcdecff9a5966c904d4a90acdf691.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate261_jpg.rf.c5b6cba76f01bace869963c3e9c6c221.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate262_jpg.rf.47afaabb65bd1be9db23b954ef0f2a2a.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate263_jpg.rf.8f351900ce5be124f2f1e922079f6633.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate265_jpg.rf.3ba0a31d8f186c0c7210112356b40b65.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate266_jpg.rf.83d1a96a1e7523afc621e33729d4db64.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate267_jpg.rf.0d9c55372849c9b046a58d1f6b4b0986.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate268_jpg.rf.a4549e1cc40845d814485c53c0bce1a1.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate269_jpg.rf.eab6037cca353e43167f46d402490d5c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate26_jpg.rf.cf444fbc994b47dabe7e701a806f05aa.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate270_jpg.rf.a1200513624b12f313381b04109a1f7f.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate271_jpg.rf.00bc9268b90d108718b358adde6b8197.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate272_jpg.rf.2b0cef3b0f25d7bdc21c9b2dfe398030.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate274_jpg.rf.af122cbe2d965d5cce30fa0742867037.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate275_jpg.rf.2dd8db828f7bc4d2fea16eda34406abb.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate276_jpg.rf.0fcc848deac09b9967768da46f2b8761.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate277_jpg.rf.467cd79c274a37974b5ef66bf7db16e3.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate278_jpg.rf.476bfd14310fc9fa396e2e7fc252f69d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate279_jpg.rf.b1db0ed40735488f12b1a5cd93297efe.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate27_jpg.rf.a3e99e6c313aef64e33d3d4bab381692.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate280_jpg.rf.d6a6b08d1cee9d5851a1710f39749bbd.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate281_jpg.rf.1a869c72cb46ffc507c13febbd820769.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate283_jpg.rf.76a1861a7c695c1110b548c3c0524bfc.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate284_jpg.rf.0d927209c26e51afc3d4eac711a76c9a.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate285_jpg.rf.37ff6b2b1744635665b87b385604efe0.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate286_jpg.rf.dd9956e92256e15d7c62f8c890a153ee.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate287_jpg.rf.3c49083d17f2b57eadde93fa52219a77.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate288_jpg.rf.b4e2e724ea30e039365b555cd3aa5f0c.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate289_jpg.rf.dfe9c7b4304bff0a1250d5c36b1d0ace.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate28_jpg.rf.4b7dd52497da1416106b1e0cf90606d7.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate290_jpg.rf.c401d01a0097fbe1f1ca5dd10ee25406.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate291_jpg.rf.8d340ef4f29684436f1162d71ceb9e28.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate292_jpg.rf.61826ba4e1fb5d8015e059709e039b4d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate293_jpg.rf.699fed867cd4a25e098c7ca1c810e6b2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate295_jpg.rf.31f71e136f53cf98f6e6b8831114c65d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate296_jpg.rf.789413c6de991e3412f1e2c4a84f582d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate297_jpg.rf.6c6228d16b60c7a8d518381a9aee5e10.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate298_jpg.rf.a162a27973fb97d158111e513c345ce4.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate299_jpg.rf.801a589d4f37781922e6a120da685520.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate29_jpg.rf.5044e60163e069f269ad1e8942496e6d.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate2_jpg.rf.b9534deca473c03586893417b48c7481.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate300_jpg.rf.9929161513a4b453a37daf4ba7d1a6f2.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate301_jpg.rf.35480de629271b5a84145b5cc2179bfc.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate304_jpg.rf.55a673ca62cdc2bae0cf22ec2f90c414.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate305_jpg.rf.1a1513b5ecdacc142e3b21dbccd451d1.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate306_jpg.rf.68d9c6c6f863769ea8fb6c68683a5c26.jpg
#   inflating: /content/coco-format-number-plate-dataset/train/CarLongPlate307_jpg.rf.d12df7f5d8028c1b005a3676e36b83ec.jpg
# ...
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen733_jpg.rf.541b5912d03f0ce65649dc0eba94ffc9.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen734_jpg.rf.9c35f762fe3f5fc7e516ba69071a0d7b.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen736_jpg.rf.9fde881830d80eb0639158d11662851c.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen739_jpg.rf.6dd1fdcdee75565bb7d7a64c7c38174d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen740_jpg.rf.c3063ea05a9f5649bc11408326736704.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen741_jpg.rf.3c3a4499efea8c7c7f268b32a614a70b.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen744_jpg.rf.3a4593a71887a5d155b4a0770b0cf1f3.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen746_jpg.rf.07b8bdbde5e063c59f054ef842b6fbf6.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen748_jpg.rf.b83233afbb469976c3dfc8fb39cf5296.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen74_jpg.rf.5744abd9e4bc097b56e73a7c73987e58.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen757_jpg.rf.97f70ba79ff755f7470431fc3e88b97a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen765_jpg.rf.1c77b3101a5586b079a0a5447c58f004.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen769_jpg.rf.57b0ba453477ffa2d29e1c4f83706381.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen774_jpg.rf.2c2f1c1afa9dd97434ca6c1917fdfd26.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen783_jpg.rf.4560257314b8abc05bfc2fcdbc779134.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen788_jpg.rf.0b5013e5f1e944e06150dfc6cc0bb1cc.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen789_jpg.rf.a3b8c709ff8aaaff3a3d5f40e1d2f699.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen794_jpg.rf.3eafae74f6b50c0fdb24cda672b01521.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen797_jpg.rf.936fe7a767d736bee9361285d5cd8783.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen805_jpg.rf.1155fc066ab090bb0c99870938960a3c.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen812_jpg.rf.f35980326bb530a86ed4379769ffd97d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen813_jpg.rf.170297b45be22b6676a3c592ce54423f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen814_jpg.rf.464660cecd29d87a2ee960f78977fa58.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen818_jpg.rf.b875ea70fa6447be50a62edf3dbab0ba.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen822_jpg.rf.b7b6cd01bc96c2b6989cfd6620b4840e.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen826_jpg.rf.4fa276fea350342bf8f677a144a47484.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen82_jpg.rf.cd346a975cde7da36afd4307e137ad8a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen836_jpg.rf.230cb5f6cbe33c49818673e3181cf516.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen845_jpg.rf.afced14e7370df17ef448431cb0ebb6c.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen859_jpg.rf.e0db029a7e5f05facb9edc14e4b50b31.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen864_jpg.rf.6ebcf818263aa100c3bec3cc65ffbaf8.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen866_jpg.rf.380913db0b8e49bf02cd0f5a908377fc.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen869_jpg.rf.3b58bbe4d01c4024ca090ea5fef2fa5a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen873_jpg.rf.0e67fccc58efdc9063d2a10b910be1ed.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen885_jpg.rf.fbe76e65966726a366cfbf43644d6d60.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen886_jpg.rf.fcf8447ec645b7b9d5093421e10229ed.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen892_jpg.rf.d784d486a95f13ef83d782ad57049a7a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen893_jpg.rf.1880cd0fefb30babfa8f98d924785399.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen896_jpg.rf.631b5898855df9948f0bc051ba58aecb.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen919_jpg.rf.5c5d2b9a15f77d2b26211674e62a2732.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen920_jpg.rf.c61fa48db5e81c6660bfacf14e14f94e.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen92_jpg.rf.f293bbb2905bd1452f371b776a2a42cc.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen930_jpg.rf.cce4088f1b80461a57ce0da6c8128ecc.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen939_jpg.rf.1802332c2e08dd80b7af0b09863c648a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen945_jpg.rf.2cbcf06477e46bfbd4b3765696d5459d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen948_jpg.rf.52ed0e261270960ff8213d7d9e5dfcda.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen94_jpg.rf.a3f404c99cfbf06f8be2cea13aaab310.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen950_jpg.rf.a7112bcaeed8ba571f73c1d8cad27361.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen952_jpg.rf.313212c1e8509ca10e9db228eb509ccf.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen959_jpg.rf.557f1ae51a34e74afd7574c5e8534579.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen963_jpg.rf.650d9ff9cedb033a5dfbb49cc803e99d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen964_jpg.rf.6964ce39c768bea5fc8bd59286995da2.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen969_jpg.rf.4477387b886b491cf3c9b6b191ad0061.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen976_jpg.rf.481c2bc9afb894d58c7336108229d39f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen977_jpg.rf.1b9782b157630db054aeee71232c77b3.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen978_jpg.rf.24222599bf21a0b1c771333308dd5c8d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen981_jpg.rf.c65440b61292a237046649154f0272fb.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen991_jpg.rf.fe6b391fb0b439d235ae79979260ddf6.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/CarLongPlateGen9_jpg.rf.a52eed694dd0ec1b56a709399c495afb.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars106_png.rf.338a176fc058ee6f1daa4205d7d0418e.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars111_png.rf.b3be4e9927a82109fd9cd0b755ffbea1.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars134_png.rf.84972aae8c4d45863909115150e63132.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars135_png.rf.3a12a98b42570634d7bf3849e58cc443.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars136_png.rf.0460581b114250ed1e0ffb2739933dc8.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars150_png.rf.8dee2b6e0ea5504cd7a5bc844a8a8bf6.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars156_png.rf.6d94e7c3fc8d3c82389e8d4cd4f3403c.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars170_png.rf.d8daa71cca60271043395ebaf574c473.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars177_png.rf.9ce0ae8a743779504bf9429fbd53c393.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars185_png.rf.8ce6cc9b55d183f1552809629b1af99e.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars188_png.rf.2a06fa8e8652de9fc268ddd7ba98272a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars190_png.rf.47b971f629b2791b7ecf8aeaa325542a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars213_png.rf.82895fb6cd28c887135575eaf96e2166.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars214_png.rf.b6cae9f2875281fc8640f4e63db5f495.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars225_png.rf.779af4a2a8fa2d7eb9555bb9152dba1e.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars229_png.rf.1bca0adb55f8d44af63767b764ed06f8.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars235_png.rf.8eb4313c48f3e3397bb14cd903dc37e3.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars243_png.rf.b468290887e24fcf176b5f75124e1bc9.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars254_png.rf.b890b76cc520af4044c108ea7d78c1fa.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars263_png.rf.de58de0fce8852e90eb173c9792388a4.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars264_png.rf.347845e29066a3bcf71c9a4a4ac789da.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars27_png.rf.51d88dfa492b86b5c78f41c3a48dec7d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars281_png.rf.36d3a64abd67cdfd81390a31418188cc.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars294_png.rf.34043bc197b1071fd184152a5b11f374.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars296_png.rf.fc15565a9ff1d98303d1fa0fb06faa1f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars2_png.rf.5a61b914b095443d43363ee96d1c31a0.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars311_png.rf.eb634bde441a90066e9490b76ca220a7.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars330_png.rf.9fa208dc37eda017cbe0c50bd34d5c54.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars349_png.rf.3dc44d3353dc95fa716682620c619b24.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars360_png.rf.e990ddd78bc85aac2e4d688aaf9eebdb.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars392_png.rf.74bf83ada63f0e992ca6e62d3f5d84a2.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars404_png.rf.38d302bf102f7f350833b1a1e089a030.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars409_png.rf.ce37ecdcee35bc1a60a279721d2a8cf2.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars411_png.rf.0a25010595ad6b3ff04ef99fdb6bf780.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars415_png.rf.09689dd376e4571988f4534141ba3421.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars427_png.rf.b79c026d0c548a511a96c46fe0b69815.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars430_png.rf.bd61cb327001e018a32f93780f68f4aa.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars44_png.rf.7ec7c9b9c7ff0fca7c3e3c4808d15aec.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars45_png.rf.f89e2127d0e47cd156fbbc2e45ae3ac2.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars5_png.rf.52584a5736e0952a1eaeb019f7945b76.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars63_png.rf.87b0750b733cbde638d1ccd507ce0ca0.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars6_png.rf.f39e3766d4108c200745f88b07711849.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/Cars93_png.rf.86da52d997e6afdeb3c1eadd4e0e6ea8.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/_annotations.coco.json
#   inflating: /content/coco-format-number-plate-dataset/valid/boderngoaigiao14_jpg.rf.04f3721789f762dc6827734a01e3b079.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderngoaigiao2_jpg.rf.880fcc96cf470920900408b0b5760de7.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderngoaigiao5_jpg.rf.16623f212bfa5be107ca6594ee388f33.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi105_jpg.rf.6d3e94f097327da5b28a4207ea2e9842.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi27_jpg.rf.8a60ff77ffd4547076d717e889b7aedd.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi29_jpg.rf.45bd54450bf8f787ff7716b5f76a4a5a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi30_jpg.rf.1f468dd0171e1ed74c204a9a130b1b72.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi42_jpg.rf.f459ad92b3d25230b84f96d6d4c0458f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi55_jpg.rf.a84bb64baf30a709584cbd10038e8626.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi67_jpg.rf.ea73cc9017c1cfc0eccb78ad624218e3.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi70_jpg.rf.3211b42b520e51295a2350467723ad4d.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi73_jpg.rf.ec95ee6141c882ca0e41e695c649b0c3.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi8_jpg.rf.40e747b021975cbba2ebabc0756c6024.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi94_jpg.rf.f97e712b66577e87f6578aec51941408.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi96_jpg.rf.ee054ac5d78dbd8b4efc0eaf2be57179.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/boderquandoi9_jpg.rf.4eb2ddf03b123bc2a2cdefdb1035343f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessngoaigiao11_jpg.rf.a41b6a4dff7ddfbd7ef2f72a36ce9470.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessngoaigiao8_jpg.rf.7e9ac0a2f3ce620ee4cfd0812a233730.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi102_jpg.rf.498804507063c6945a1e820c3e612593.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi104_jpg.rf.ded86f731a3a461c24d8a8d4884d7e21.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi109_jpg.rf.942ae64896ef59414e8a094a20b86880.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi110_jpg.rf.aafd33a5218c4e3263bbcd11811b857f.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi28_jpg.rf.327645589cc67c18df43f50103276d59.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi39_jpg.rf.044d079848dbf77cdb9688348ffe2037.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi3_jpg.rf.41e895bb0983e9818759b98090eb113a.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi43_jpg.rf.79ff63f2f43c84657386d82807516a13.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi5_jpg.rf.d267279a47ef054793eef4e426928325.jpg
#   inflating: /content/coco-format-number-plate-dataset/valid/brightnessquandoi99_jpg.rf.785c24b5509ef077267a8a401bc21bf3.jpg

# %%
# !cd /content/coco-format-number-plate-dataset && ls
# Out:
# README.dataset.txt  README.roboflow.txt  test  train  valid

# %% [markdown]
# MY **MODEL**

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 24.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.5 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 22.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# **already available model**

# %%
import torchvision
import os

class CocoDetection(torchvision.datasets.CocoDetection):
    def __init__(self, img_folder, feature_extractor, train=True):
        ann_file = os.path.join(img_folder, "_annotations.coco.json")
        super(CocoDetection, self).__init__(img_folder, ann_file)
        self.feature_extractor = feature_extractor

    def __getitem__(self, idx):
        # read in PIL image and target in COCO format
        img, target = super(CocoDetection, self).__getitem__(idx)

        # preprocess image and target (converting target to DETR format, resizing + normalization of both image and target)
        image_id = self.ids[idx]
        target = {'image_id': image_id, 'annotations': target}
        encoding = self.feature_extractor(images=img, annotations=target, return_tensors="pt")
        pixel_values = encoding["pixel_values"].squeeze() # remove batch dimension
        target = encoding["labels"][0] # remove batch dimension

        return pixel_values, target

# %% [markdown]
# Based on the class defined above, we create training and validation datasets.

# %%
from transformers import DetrFeatureExtractor

img_folder = "/content/coco-format-number-plate-dataset"

feature_extractor = DetrFeatureExtractor.from_pretrained("facebook/detr-resnet-50")

train_dataset = CocoDetection(img_folder=f'{img_folder}/train', feature_extractor=feature_extractor)
val_dataset = CocoDetection(img_folder=f'{img_folder}/valid', feature_extractor=feature_extractor, train=False)
test_dataset = CocoDetection(img_folder=f'{img_folder}/test', feature_extractor=feature_extractor, train=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/290 [00:00<?, ?B/s]
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.11/dist-packages/transformers/models/detr/feature_extraction_detr.py:38: FutureWarning: The class DetrFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use DetrImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# As you can see, this dataset is tiny:

# %%
train_dataset
# Out:
# Dataset CocoDetection
#     Number of datapoints: 3081
#     Root location: /content/coco-format-number-plate-dataset/train

# %%
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(val_dataset))
print("Number of testing examples:", len(test_dataset))
# Out:
# Number of training examples: 3081
# Number of validation examples: 579
# Number of testing examples: 195

# %% [markdown]
# Let's verify an example by visualizing it. We can access the COCO API of the dataset by typing `train_dataset.coco`.

# %%
import numpy as np
import os
from PIL import Image, ImageDraw

# based on https://github.com/woctezuma/finetune-detr/blob/master/finetune_detr.ipynb
image_ids = train_dataset.coco.getImgIds()
# let's pick a random image
image_id = image_ids[np.random.randint(0, len(image_ids))]
print('Image n°{}'.format(image_id))
image = train_dataset.coco.loadImgs(image_id)[0]
image = Image.open(os.path.join(f'{img_folder}/train', image['file_name']))

annotations = train_dataset.coco.imgToAnns[image_id]
draw = ImageDraw.Draw(image, "RGBA")

cats = train_dataset.coco.cats
id2label = {k: v['name'] for k,v in cats.items()}

for annotation in annotations:
  box = annotation['bbox']
  class_idx = annotation['category_id']
  x,y,w,h = tuple(box)
  draw.rectangle((x,y,x+w,y+h), outline='red', width=1)
  draw.text((x, y), id2label[class_idx], fill='white')

image
# Out:
# Image n°1297
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>

# %% [markdown]
# Next, let's create corresponding dataloaders. We define a custom `collate_fn` to batch images together. As DETR resizes images to have a min size of 800 and a max size of 1333, images can have different sizes. We pad images (`pixel_values`) to the largest image in a batch, and create a corresponding `pixel_mask` to indicate which pixels are real (1)/which are padding (0).

# %%
train_dataset.coco

# %%
cats
# Out:
# {0: {'id': 0, 'name': 'plate', 'supercategory': 'none'},
#  1: {'id': 1, 'name': 'licence', 'supercategory': 'plate'},
#  2: {'id': 2, 'name': 'plate', 'supercategory': 'plate'}}

# %%
from torch.utils.data import DataLoader

def collate_fn(batch):
  pixel_values = [item[0] for item in batch]
  encoding = feature_extractor.pad(pixel_values, return_tensors="pt")
  labels = [item[1] for item in batch]
  batch = {}
  batch['pixel_values'] = encoding['pixel_values']
  batch['pixel_mask'] = encoding['pixel_mask']
  batch['labels'] = labels
  return batch

train_dataloader = DataLoader(train_dataset, collate_fn=collate_fn, batch_size=10, shuffle=True)
val_dataloader = DataLoader(val_dataset, collate_fn=collate_fn, batch_size=10)
test_dataloader = DataLoader(test_dataset, collate_fn=collate_fn, batch_size=10)

batch = next(iter(train_dataloader))

# %% [markdown]
# Let's verify the keys of a single batch:

# %%
batch.keys()
# Out:
# dict_keys(['pixel_values', 'pixel_mask', 'labels'])

# %% [markdown]
# Let's verify the shape of the `pixel_values`, and check the `target`::

# %%
pixel_values, target = train_dataset[0]

# %%
pixel_values.shape
# Out:
# torch.Size([3, 800, 800])

# %%
print(target)
# Out:
# {'size': tensor([800, 800]), 'image_id': tensor([0]), 'class_labels': tensor([2]), 'boxes': tensor([[0.3960, 0.2758, 0.2440, 0.1094]]), 'area': tensor([17079.3262]), 'iscrowd': tensor([0]), 'orig_size': tensor([416, 416])}

# %% [markdown]
# ## Train the model using PyTorch Lightning
#
# Here we define a `LightningModule`, which is an `nn.Module` with some extra functionality.
#
# For more information regarding PyTorch Lightning, I recommend the [docs](https://pytorch-lightning.readthedocs.io/en/latest/?_ga=2.35105442.2002381006.1623231889-1738348008.1615553774) as well as the [tutorial notebooks](https://github.com/PyTorchLightning/lightning-tutorials/tree/aeae8085b48339e9bd9ab61d81cc0dc8b0d48f9c/.notebooks/starters).
#
# You can of course just train the model in native PyTorch as an alternative.

# %%
import pytorch_lightning as pl
from transformers import DetrConfig, DetrForObjectDetection
import torch
from torchvision import models

import torch.nn as nn

class VGG16Backbone(nn.Module):
    def __init__(self):
        super(VGG16Backbone, self).__init__()
        # Load the pre-trained VGG16 model
        vgg = models.vgg16(pretrained=True)
        self.features = vgg.features  # Convolutional layers
        # Output the last feature map size as required for DETR
        self.out_channels = 512  # VGG-16's last convolutional layer has 512 channels

    def forward(self, x):
        return self.features(x)


class Detr(pl.LightningModule):

     def __init__(self, lr, lr_backbone, weight_decay):
         super().__init__()

         config = DetrConfig.from_pretrained("facebook/detr-resnet-50", num_labels=3, ignore_mismatched_sizes=True)
        # Use the custom VGG16 backbone instead of the default ResNet backbone
         self.model = DetrForObjectDetection(config)
         self.model.backbone = VGG16Backbone()  # Replacing ResNet with VGG16 backbone
         # replace COCO classification head with custom head
         self.model = DetrForObjectDetection.from_pretrained("facebook/detr-resnet-50",
                                                             num_labels=len(id2label),
                                                             ignore_mismatched_sizes=True)
         # see https://github.com/PyTorchLightning/pytorch-lightning/pull/1896
         self.lr = lr
         self.lr_backbone = lr_backbone
         self.weight_decay = weight_decay

     def forward(self, pixel_values, pixel_mask):
       outputs = self.model(pixel_values=pixel_values, pixel_mask=pixel_mask)

       return outputs

     def common_step(self, batch, batch_idx):
       pixel_values = batch["pixel_values"]
       pixel_mask = batch["pixel_mask"]
       labels = [{k: v.to(self.device) for k, v in t.items()} for t in batch["labels"]]

       outputs = self.model(pixel_values=pixel_values, pixel_mask=pixel_mask, labels=labels)

       loss = outputs.loss
       loss_dict = outputs.loss_dict

       return loss, loss_dict

     def training_step(self, batch, batch_idx):
        loss, loss_dict = self.common_step(batch, batch_idx)
        # logs metrics for each training_step,
        # and the average across the epoch
        self.log("training_loss", loss)
        for k,v in loss_dict.items():
          self.log("train_" + k, v.item())

        return loss

     def validation_step(self, batch, batch_idx):
        loss, loss_dict = self.common_step(batch, batch_idx)
        self.log("validation_loss", loss)
        for k,v in loss_dict.items():
          self.log("validation_" + k, v.item())

        return loss

     def configure_optimizers(self):
        param_dicts = [
              {"params": [p for n, p in self.named_parameters() if "backbone" not in n and p.requires_grad]},
              {
                  "params": [p for n, p in self.named_parameters() if "backbone" in n and p.requires_grad],
                  "lr": self.lr_backbone,
              },
        ]
        optimizer = torch.optim.AdamW(param_dicts, lr=self.lr,
                                  weight_decay=self.weight_decay)

        return optimizer

     def train_dataloader(self):
        return train_dataloader

     def val_dataloader(self):
        return val_dataloader

# %% [markdown]
# We could start Tensorboard if we'd like to monitor the training, since Pytorch Lightning automatically logs to it.

# %%
# Start tensorboard.
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs/
# Out:
#       <iframe id="tensorboard-frame-6d2f734edf908a46" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6d2f734edf908a46");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Here we define the model, and verify the outputs.

# %%
model = Detr(lr=1e-4, lr_backbone=1e-5, weight_decay=1e-4)

outputs = model(pixel_values=batch['pixel_values'], pixel_mask=batch['pixel_mask'])
# Out:
# config.json:   0%|          | 0.00/4.59k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:06<00:00, 82.6MB/s]
# model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DetrForObjectDetection were not initialized from the model checkpoint at facebook/detr-resnet-50 and are newly initialized because the shapes did not match:
# - class_labels_classifier.bias: found shape torch.Size([92]) in the checkpoint and torch.Size([4]) in the model instantiated
# - class_labels_classifier.weight: found shape torch.Size([92, 256]) in the checkpoint and torch.Size([4, 256]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The logits are of shape `(batch_size, num_queries, number of classes + 1)`. We model internally adds an additional "no object class", which explains why we have one additional output for the class dimension.

# %%
outputs.logits.shape
# Out:
# torch.Size([10, 100, 4])

# %% [markdown]
# Next, let's train! We train for a maximum of 300 training steps, and also use gradient clipping. You can refresh Tensorboard above to check the various losses.

# %%
from pytorch_lightning import Trainer
from tqdm.notebook import tqdm
from torchmetrics import Accuracy

trainer = Trainer(max_epochs=10, gradient_clip_val=0.1)
trainer.fit(model)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                   | Params | Mode
# --------------------------------------------------------
# 0 | model | DetrForObjectDetection | 41.5 M | eval
# --------------------------------------------------------
# 41.3 M    Trainable params
# 222 K     Non-trainable params
# 41.5 M    Total params
# 166.009   Total estimated model params size (MB)
# 0         Modules in train mode
# 399       Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=10` reached.

# %%
trainer.callback_metrics  # Returns a dictionary of logged metrics
# Out:
# {'training_loss': tensor(0.6983),
#  'train_loss_ce': tensor(0.0007),
#  'train_loss_bbox': tensor(0.0274),
#  'train_loss_giou': tensor(0.2803),
#  'train_cardinality_error': tensor(0.),
#  'validation_loss': tensor(0.6187),
#  'validation_loss_ce': tensor(0.0243),
#  'validation_loss_bbox': tensor(0.0283),
#  'validation_loss_giou': tensor(0.2264),
#  'validation_cardinality_error': tensor(0.0812)}

# %% [markdown]
# For the training I used [Sagemaker Studio Lab](https://studiolab.sagemaker.aws/) which offers performant GPUs. So don't hesitate to reduce the batch size if you run into memory errors.

# %%
# !nvidia-smi
# Out:
# Mon Jan 27 10:06:31 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0              33W /  70W |    159MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Inference (+ visualization)
#
# Let's visualize the predictions of DETR on the first image of the validation set.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
model.eval()
# Out:
# Detr(
#   (model): DetrForObjectDetection(
#     (model): DetrModel(
#       (backbone): DetrConvModel(
#         (conv_encoder): DetrConvEncoder(
#           (model): FeatureListNet(
#             (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#             (bn1): DetrFrozenBatchNorm2d()
#             (act1): ReLU(inplace=True)
#             (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#             (layer1): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): DetrFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer2): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DetrFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (3): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer3): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DetrFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (3): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (4): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (5): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer4): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DetrFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DetrFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DetrFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DetrFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#         (position_embedding): DetrSinePositionEmbedding()
#       )
#       (input_projection): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       (query_position_embeddings): Embedding(100, 256)
#       (encoder): DetrEncoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrEncoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (activation_fn): ReLU()
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (decoder): DetrDecoder(
#         (layers): ModuleList(
#           (0-5): 6 x DetrDecoderLayer(
#             (self_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): DetrAttention(
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=256, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (layernorm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (class_labels_classifier): Linear(in_features=256, out_features=4, bias=True)
#     (bbox_predictor): DetrMLPPredictionHead(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         (2): Linear(in_features=256, out_features=4, bias=True)
#       )
#     )
#   )
# )

# %%
# Out:
# {'training_loss': tensor(1.8356),
#  'train_loss_ce': tensor(0.3049),
#  'train_loss_bbox': tensor(0.1331),
#  'train_loss_giou': tensor(0.4327),
#  'train_cardinality_error': tensor(1.),
#  'validation_loss': tensor(1.7175),
#  'validation_loss_ce': tensor(0.3136),
#  'validation_loss_bbox': tensor(0.1101),
#  'validation_loss_giou': tensor(0.4267),
#  'validation_cardinality_error': tensor(1.)}

# %%
import torch
import matplotlib.pyplot as plt

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{id2label[cl.item()]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
def visualize_predictions(image, outputs, threshold=0.9, keep_highest_scoring_bbox=False):
  # keep only predictions with confidence >= threshold
  probas = outputs.logits.softmax(-1)[0, :, :-1]
  keep = probas.max(-1).values > threshold
  if keep_highest_scoring_bbox:
    keep = probas.max(-1).values.argmax()
    keep = torch.tensor([keep])

  # convert predicted boxes from [0; 1] to image scales
  bboxes_scaled = rescale_bboxes(outputs.pred_boxes[0, keep].cpu(), image.size)

  # plot results
  plot_results(image, probas[keep], bboxes_scaled)

# %%
it = iter(range(1500))

# %%
#We can use the image_id in target to know which image it is
pixel_values, target = val_dataset[next(it)]

pixel_values = pixel_values.unsqueeze(0).to(device)
print(pixel_values.shape)

# forward pass to get class logits and bounding boxes
outputs = model(pixel_values=pixel_values, pixel_mask=None)

image_id = target['image_id'].item()
image = val_dataset.coco.loadImgs(image_id)[0]
image = Image.open(os.path.join(f'{img_folder}/valid', image['file_name']))

visualize_predictions(image, outputs, threshold=0.3, keep_highest_scoring_bbox=True)
# Out:
# torch.Size([1, 3, 800, 800])

# %%
TEST_DATASET = test_dataset

# %%
# !pip install supervision
# Out:
# Collecting supervision
#   Downloading supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.11/dist-packages (from supervision) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Downloading supervision-0.25.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 15.5 MB/s eta 0:00:00
# Installing collected packages: supervision
# Successfully installed supervision-0.25.1

# %%
import supervision as sv

# %%
from transformers import DetrForObjectDetection, DetrImageProcessor
CHECKPOINT = 'facebook/detr-resnet-50'

image_processor = DetrImageProcessor.from_pretrained(CHECKPOINT)

# %%
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# utils
categories = TEST_DATASET.coco.cats
id2label = {k: v['name'] for k,v in categories.items()}
box_annotator = sv.BoxAnnotator()

# select random image
image_ids = TEST_DATASET.coco.getImgIds()
image_id = random.choice(image_ids)
print('Image #{}'.format(image_id))

# load image and annotatons
image = TEST_DATASET.coco.loadImgs(image_id)[0]
annotations = TEST_DATASET.coco.imgToAnns[image_id]
image_path = os.path.join(TEST_DATASET.root, image['file_name'])
image = cv2.imread(image_path)

# annotate
detections = sv.Detections.from_coco_annotations(coco_annotation=annotations)
labels = [f"{id2label[class_id]}" for _, _, class_id, _ in detections]
frame_ground_truth = box_annotator.annotate(scene=image.copy(), detections=detections, labels=labels)

# inference
with torch.no_grad():

    # load image and predict
    inputs = image_processor(images=image, return_tensors='pt').to(device)
    outputs = model(**inputs)

    # post-process
    target_sizes = torch.tensor([image.shape[:2]]).to(device)
    results = image_processor.post_process_object_detection(
        outputs=outputs,
        threshold=0.5,
        target_sizes=target_sizes
    )[0]

# annotate
detections = sv.Detections.from_transformers(transformers_results=results)
labels = [f"{id2label[class_id]} {confidence:.2f}" for _, confidence, class_id, _ in detections]
frame_detections = box_annotator.annotate(scene=image.copy(), detections=detections, labels=labels)


# %matplotlib inline # Remove this line, we won't use it anymore

# Combine both images side by side and display
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(cv2.cvtColor(frame_ground_truth, cv2.COLOR_BGR2RGB))
axs[0].axis('off')
axs[0].set_title('Ground Truth')

axs[1].imshow(cv2.cvtColor(frame_detections, cv2.COLOR_BGR2RGB))
axs[1].axis('off')
axs[1].set_title('Detections')
# Out:
# Image #70
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9852988b07ec> in <cell line: 0>()
#      21
#      22 # annotate
# ---> 23 detections = sv.Detections.from_coco_annotations(coco_annotation=annotations)
#      24 labels = [f"{id2label[class_id]}" for _, _, class_id, _ in detections]
#      25 frame_ground_truth = box_annotator.annotate(scene=image.copy(), detections=detections, labels=labels)
#
# AttributeError: type object 'Detections' has no attribute 'from_coco_annotations'

# %%
# !pip install -q coco_eval

# %%
def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)

def prepare_for_coco_detection(predictions):
    coco_results = []
    for original_id, prediction in predictions.items():
        if len(prediction) == 0:
            continue

        boxes = prediction["boxes"]
        boxes = convert_to_xywh(boxes).tolist()
        scores = prediction["scores"].tolist()
        labels = prediction["labels"].tolist()

        coco_results.extend(
            [
                {
                    "image_id": original_id,
                    "category_id": labels[k],
                    "bbox": box,
                    "score": scores[k],
                }
                for k, box in enumerate(boxes)
            ]
        )
    return coco_results

# %%
from coco_eval import CocoEvaluator
from tqdm.notebook import tqdm

import numpy as np

evaluator = CocoEvaluator(coco_gt=TEST_DATASET.coco, iou_types=["bbox"])

print("Running evaluation...")

for idx, batch in enumerate(tqdm(test_dataloader)):
    pixel_values = batch["pixel_values"].to(device)
    pixel_mask = batch["pixel_mask"].to(device)
    labels = [{k: v.to(device) for k, v in t.items()} for t in batch["labels"]]

    with torch.no_grad():
      outputs = model(pixel_values=pixel_values, pixel_mask=pixel_mask)

    orig_target_sizes = torch.stack([target["orig_size"] for target in labels], dim=0)
    results = image_processor.post_process_object_detection(outputs, target_sizes=orig_target_sizes)

    predictions = {target['image_id'].item(): output for target, output in zip(labels, results)}
    predictions = prepare_for_coco_detection(predictions)
    evaluator.update(predictions)

evaluator.synchronize_between_processes()
evaluator.accumulate()
evaluator.summarize()
# Out:
# Running evaluation...
#   0%|          | 0/20 [00:00<?, ?it/s]
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.341
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.588
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.217
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.458
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.538
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775

# %%
trainer.save_checkpoint("detr_model.ckpt")

# %% [markdown]
# I hope you find this notebook useful. If you have any questions, please don't hesitate to contact me.
#
# Also note that this is only the license plate detection part, we can also use this model for the characters segmentation , followed by an OCR. (you can check [this paper](https://www.researchgate.net/publication/353034031_An_Improved_Character_Recognition_Framework_for_Containers_Based_on_DETR_Algorithm) for more info)
#
# ![](https://www.mdpi.com/sensors/sensors-21-04612/article_deploy/html/images/sensors-21-04612-g001.png)
#
# Unfortunately I'm quite busy lately, but I'll try to post the rest of the notebooks soon.
